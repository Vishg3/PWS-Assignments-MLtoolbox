# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df=pd.read_csv('Travel.csv')

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
df.shape
# Out:
# (4888, 20)

# %%
df.dtypes
# Out:
# CustomerID                    int64
# ProdTaken                     int64
# Age                         float64
# TypeofContact                object
# CityTier                      int64
# DurationOfPitch             float64
# Occupation                   object
# Gender                       object
# NumberOfPersonVisiting        int64
# NumberOfFollowups           float64
# ProductPitched               object
# PreferredPropertyStar       float64
# MaritalStatus                object
# NumberOfTrips               float64
# Passport                      int64
# PitchSatisfactionScore        int64
# OwnCar                        int64
# NumberOfChildrenVisiting    float64
# Designation                  object
# MonthlyIncome               float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
cat_cols=[col for col in df.columns if df[col].dtype=='object']
num_cols=[col for col in df.columns if df[col].dtype!='object']

# %%
cat_cols
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
df[cat_cols].isnull().sum()
# Out:
# TypeofContact     25
# Occupation         0
# Gender             0
# ProductPitched     0
# MaritalStatus      0
# Designation        0
# dtype: int64

# %%
df[num_cols].isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# CityTier                      0
# DurationOfPitch             251
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# PreferredPropertyStar        26
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# MonthlyIncome               233
# dtype: int64

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# CustomerID                  0
# ProdTaken                   0
# Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# dtype: int64

# %%
for col in cat_cols:
    print(col,':',df[col].unique())
    print()
# Out:
# TypeofContact : ['Self Enquiry' 'Company Invited']
#
# Occupation : ['Salaried' 'Free Lancer' 'Small Business' 'Large Business']
#
# Gender : ['Female' 'Male' 'Fe Male']
#
# ProductPitched : ['Deluxe' 'Basic' 'Standard' 'Super Deluxe' 'King']
#
# MaritalStatus : ['Single' 'Divorced' 'Married' 'Unmarried']
#
# Designation : ['Manager' 'Executive' 'Senior Manager' 'AVP' 'VP']

# %%
df.head(2)
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
#
#   Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0   Salaried  Female                       3                3.0
# 1   Salaried    Male                       3                4.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0         Deluxe                    3.0        Single            1.0
# 1         Deluxe                    4.0      Divorced            2.0
#
#    Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 0         1                       2       1                       0.0
# 1         0                       3       1                       2.0
#
#   Designation  MonthlyIncome
# 0     Manager        20993.0
# 1     Manager        20130.0

# %%
df['Gender']=df['Gender'].replace(to_replace='Fe Male',value='Female')

# %%
df.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
cat_cols
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
num_cols
# Out:
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
df.sample()
# Out:
#      CustomerID  ProdTaken   Age TypeofContact  CityTier  DurationOfPitch  \
# 819      200819          0  28.0  Self Enquiry         1              8.0
#
#     Occupation Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 819   Salaried   Male                       3                4.0
#
#     ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 819          Basic                    4.0      Divorced            1.0
#
#      Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 819         0                       2       0                       2.0
#
#     Designation  MonthlyIncome
# 819   Executive        18201.0

# %%
df.drop('CustomerID',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['ProdTaken', 'Age', 'TypeofContact', 'CityTier', 'DurationOfPitch',
#        'Occupation', 'Gender', 'NumberOfPersonVisiting', 'NumberOfFollowups',
#        'ProductPitched', 'PreferredPropertyStar', 'MaritalStatus',
#        'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
#        'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
df.describe()
# Out:
#          ProdTaken          Age     CityTier  DurationOfPitch  \
# count  4128.000000  4128.000000  4128.000000      4128.000000
# mean      0.193072    37.231831     1.663275        15.584787
# std       0.394757     9.174521     0.920640         8.398142
# min       0.000000    18.000000     1.000000         5.000000
# 25%       0.000000    31.000000     1.000000         9.000000
# 50%       0.000000    36.000000     1.000000        14.000000
# 75%       0.000000    43.000000     3.000000        20.000000
# max       1.000000    61.000000     3.000000       127.000000
#
#        NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# count             4128.000000        4128.000000            4128.000000
# mean                 2.949370           3.741521               3.578488
# std                  0.718818           1.006786               0.795031
# min                  1.000000           1.000000               3.000000
# ...

# %%
#Univariate analysis

# %%
sns.histplot(data=df,x=df['Age'],kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=df,x=df['MonthlyIncome'],kde=True)
# Out:
# <Axes: xlabel='MonthlyIncome', ylabel='Count'>

# %%
sns.countplot(x=df['MaritalStatus'],data=df)
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %%
sns.countplot(x=df['Gender'],data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.Gender.value_counts(normalize=True)*100
# Out:
# Gender
# Male      59.665698
# Female    40.334302
# Name: proportion, dtype: float64

# %%
#Insights:
#Most interested people are around 35 years old
#20000 is average monthly income
#Majority people are married
#20% more people are male than female

# %%
#Bivariate analysis

# %%
df.columns
# Out:
# Index(['ProdTaken', 'Age', 'TypeofContact', 'CityTier', 'DurationOfPitch',
#        'Occupation', 'Gender', 'NumberOfPersonVisiting', 'NumberOfFollowups',
#        'ProductPitched', 'PreferredPropertyStar', 'MaritalStatus',
#        'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
#        'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
num_cols
# Out:
# ['CustomerID',
#  'ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
cat_cols
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
plt.figure(figsize=(8,8))
plt.bar(height=df['MonthlyIncome'],x=df['Age'])
plt.title('Age vs MonthlyIncome')
plt.xlabel('Age')
plt.ylabel('MonthlyIncome')
plt.show()

# %%
sns.barplot(data=df,x=df['Occupation'],y=df['NumberOfFollowups'])
# Out:
# <Axes: xlabel='Occupation', ylabel='NumberOfFollowups'>

# %%
#Insights:
#Older people have more monthy income than younger people except 37 year olds who have more than double the income of even the older people
#Free lancers on average had 1 more followup than people in other occupations

# %%
#Multivariate analysis

# %%
df.columns
# Out:
# Index(['ProdTaken', 'Age', 'TypeofContact', 'CityTier', 'DurationOfPitch',
#        'Occupation', 'Gender', 'NumberOfPersonVisiting', 'NumberOfFollowups',
#        'ProductPitched', 'PreferredPropertyStar', 'MaritalStatus',
#        'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
#        'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
num_cols
# Out:
# ['ProdTaken',
#  'Age',
#  'CityTier',
#  'DurationOfPitch',
#  'NumberOfPersonVisiting',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'Passport',
#  'PitchSatisfactionScore',
#  'OwnCar',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
cat_cols
# Out:
# ['TypeofContact',
#  'Occupation',
#  'Gender',
#  'ProductPitched',
#  'MaritalStatus',
#  'Designation']

# %%
sns.pairplot(df)
# Out:
# C:\Users\Vishg\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df[num_cols].corr(),annot=True,fmt='.1f')
plt.show()

# %%
sns.scatterplot(x=df['NumberOfPersonVisiting'],y=df['NumberOfChildrenVisiting'],data=df,hue=df['NumberOfFollowups'],palette='bright')
# Out:
# <Axes: xlabel='NumberOfPersonVisiting', ylabel='NumberOfChildrenVisiting'>

# %%
#Insights:
#People travelling in larger number are mostly familes with children
#Number of followups is more when number of people visiting is more
#Older the people product taken is lesser
