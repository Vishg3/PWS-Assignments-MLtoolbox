# %% [markdown]
# # Assignment - EDA Assignment 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df=pd.read_csv('heart_failure_clinical_records_dataset.csv')

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.shape
# Out:
# (299, 13)

# %%
df.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.sample()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 290  45.0        0                       615         1                 55
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 290                    0   222000.0               0.8           141    0
#
#      smoking  time  DEATH_EVENT
# 290        0   257            0

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
sns.distplot(df['age'],kde=True)
# Out:
# C:\Users\Vishg\AppData\Local\Temp\ipykernel_24496\3732141902.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'],kde=True)
# <Axes: xlabel='age', ylabel='Density'>

# %%
df.age.describe()
# Out:
# count    299.000000
# mean      60.833893
# std       11.894809
# min       40.000000
# 25%       51.000000
# 50%       60.000000
# 75%       70.000000
# max       95.000000
# Name: age, dtype: float64

# %%
#1 - What is the distribution of age among heart failure patients in the dataset?

#Most patients are around 60 years old
#Age is positively skewed and most people in the dataset are 40 to 70 years old
#Few very old people above 70 years old
#Oldest person is 95 years old

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
sns.boxplot(data=df,x='DEATH_EVENT',y='age')
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='age'>

# %%
sns.regplot(data=df,x='DEATH_EVENT',y='age')
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='age'>

# %%
#2 - How does the death rate vary with age?

#Death rate slightly increases with age
#Most age group who died is 55 to 75 years old
#Most age group who did not die is 50 to 65 years old
#Oldest and youngest people who died are older than oldest and youngest people who did not die

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.sex.value_counts(normalize=True)*100
# Out:
# sex
# 1    64.882943
# 0    35.117057
# Name: proportion, dtype: float64

# %%
#3 - What is the percentage of male and female patients in the dataset?

#Percent of male patients is 64.88%
#Percent of female patients is 35.11%

# %%
sns.regplot(data=df,x='age',y='platelets')
# Out:
# <Axes: xlabel='age', ylabel='platelets'>

# %%
#4 - How does the platelet count vary among different age groups?

#Platelet count almost varies same with age group. Very slight decrease in platelet count as age increases
#Platelet count is mostly between 200000 and 400000 for all age groups

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=df['serum_creatinine'],y=df['serum_sodium'])
plt.xlabel('serum_creatinine')
plt.ylabel('serum_sodium')
plt.show()

# %%
sns.heatmap(df.corr(),annot=True,fmt='.1f')
# Out:
# <Axes: >

# %%
#5 - Is there a correlation between creatinine and sodium levels in the blood?

#Correlation between creatinine and sodium levels in blood is -0.2
#Slight negative correlation which is almost insignificant

# %%
sns.barplot(data=df,x='sex',y='high_blood_pressure')
# Out:
# <Axes: xlabel='sex', ylabel='high_blood_pressure'>

# %%
df.groupby('sex')['high_blood_pressure'].mean()*100
# Out:
# sex
# 0    41.904762
# 1    31.443299
# Name: high_blood_pressure, dtype: float64

# %%
#6 - How does the prevalence of high blood pressure differ between male and female patients?

#41% females have high blood pressure
#31% males have high blood pressure

# %%
sns.countplot(data=df,x='smoking')
# Out:
# <Axes: xlabel='smoking', ylabel='count'>

# %%
df.smoking.value_counts(normalize=True)*100
# Out:
# smoking
# 0    67.892977
# 1    32.107023
# Name: proportion, dtype: float64

# %%
#7 - What is the relationship between smoking habits and the occurence of heart failure?

#32% of people with heart failure are smokers
#67% of people with heart failure are not smokers
#Majority people with heart failure are not smokers

# %%
sns.scatterplot(data=df,x='age',y='DEATH_EVENT')
# Out:
# <Axes: xlabel='age', ylabel='DEATH_EVENT'>

# %%
df.groupby('DEATH_EVENT')['age'].describe()
# Out:
#              count       mean        std   min   25%   50%   75%   max
# DEATH_EVENT
# 0            203.0  58.761906  10.637890  40.0  50.0  60.0  65.0  90.0
# 1             96.0  65.215281  13.214556  42.0  55.0  65.0  75.0  95.0

# %%
#8 - Are there any noticeable patterns in the distribution of death events across different age groups?

#There are not much noticeable patterns in the distribution of death events across different age groups
#No people above 90 have survived
#Oldest and youngest people who died are older than oldest and youngest people who did not die

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
sns.barplot(data=df,x='diabetes',y='ejection_fraction')
# Out:
# <Axes: xlabel='diabetes', ylabel='ejection_fraction'>

# %%
#9 - Is there any significant difference in ejection fraction between patients with and without diabetes?

#There is no significant difference in ejection fraction between patients with and without diabetes

# %%
sns.barplot(data=df,x='DEATH_EVENT',y='serum_creatinine')
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='serum_creatinine'>

# %%
df.groupby('DEATH_EVENT')['serum_creatinine'].mean()
# Out:
# DEATH_EVENT
# 0    1.184877
# 1    1.835833
# Name: serum_creatinine, dtype: float64

# %%
df.sample(5)
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 118  65.0        1                       113         1                 60
# 70   41.0        0                       148         0                 40
# 270  44.0        0                       582         1                 30
# 8    65.0        0                       157         0                 65
# 271  51.0        0                       582         1                 40
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 118                    1  203000.00               0.9           140    0
# 70                     0  374000.00               0.8           140    1
# 270                    1  263358.03               1.6           130    1
# 8                      0  263358.03               1.5           138    0
# 271                    0  221000.00               0.9           134    0
#
#      smoking  time  DEATH_EVENT
# 118        0    94            0
# ...

# %%
df.serum_creatinine.plot(kind='box')
# Out:
# <Axes: >

# %%
#10 - How does the serum creatinine level vary between patients who survived and those who did not?

#Patients who survived had lower serum creatinine level than those who died
#Average serum creatinine for those who survived is 1.18
#Average serum creatinine for those who died is 1.83
